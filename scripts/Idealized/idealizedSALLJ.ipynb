# %%
# import libraries

import seaborn as sns
import xarray as xr
import numpy as np
import pandas as pd
import intake
import dask
import warnings
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
warnings.filterwarnings("ignore")
ds = xr.open_dataset('../../local_data/ISCAruns/atmos_month_10y_2timesMountain2', chunks={"time": 10})
ds
# Out:
# <xarray.Dataset> Size: 4GB
# Dimensions:          (lon: 256, lonb: 257, lat: 128, latb: 129, time: 36,
#                       nv: 2, pfull: 40, phalf: 41)
# Coordinates:
#   * lon              (lon) float64 2kB 0.0 1.406 2.812 ... 355.8 357.2 358.6
#   * lonb             (lonb) float64 2kB -0.7031 0.7031 2.109 ... 357.9 359.3
#   * lat              (lat) float64 1kB -88.93 -87.54 -86.14 ... 87.54 88.93
#   * latb             (latb) float64 1kB -90.0 -88.28 -86.87 ... 86.87 88.28 90.0
#   * time             (time) object 288B 0003-01-16 00:00:00 ... 0005-12-16 00...
#   * nv               (nv) float64 16B 1.0 2.0
#   * pfull            (pfull) float64 320B 0.01722 0.07865 0.1807 ... 814.9 935.0
#   * phalf            (phalf) float64 328B 0.0 0.04682 0.1155 ... 871.5 1e+03
# Data variables: (12/32)
#     precipitation    (time, lat, lon) float32 5MB dask.array<chunksize=(10, 128, 256), meta=np.ndarray>
#     t_surf           (time, lat, lon) float32 5MB dask.array<chunksize=(10, 128, 256), meta=np.ndarray>
#     flux_lhe         (time, lat, lon) float32 5MB dask.array<chunksize=(10, 128, 256), meta=np.ndarray>
#     flux_t           (time, lat, lon) float32 5MB dask.array<chunksize=(10, 128, 256), meta=np.ndarray>
#     height           (time, pfull, lat, lon) float32 189MB dask.array<chunksize=(10, 40, 128, 256), meta=np.ndarray>
#     sphum            (time, pfull, lat, lon) float32 189MB dask.array<chunksize=(10, 40, 128, 256), meta=np.ndarray>
#     ...               ...
#     dt_vg_diffusion  (time, pfull, lat, lon) float32 189MB dask.array<chunksize=(10, 40, 128, 256), meta=np.ndarray>
#     dt_tg_diffusion  (time, pfull, lat, lon) float32 189MB dask.array<chunksize=(10, 40, 128, 256), meta=np.ndarray>
#     average_T1       (time) object 288B dask.array<chunksize=(10,), meta=np.ndarray>
#     average_T2       (time) object 288B dask.array<chunksize=(10,), meta=np.ndarray>
#     average_DT       (time) timedelta64[ns] 288B dask.array<chunksize=(10,), meta=np.ndarray>
#     time_bounds      (time, nv) timedelta64[ns] 576B dask.array<chunksize=(10, 2), meta=np.ndarray>
# Attributes:
#     filename:   atmos_month.nc
#     title:      FMS Model results
#     grid_type:  regular
#     grid_tile:  N/A

# %%
# mask out mountains
import numpy as np
Rd = 287.05
g0 = 9.80665
T0 = 270.0  # K
H = (Rd * T0) / g0

p = ds['pfull']
if p.max() < 2000:
    p_pa = p * 100.0
else:
    p_pa = p

ps = 1e5
z_levels = H * np.log(ps / p_pa)   
# height of each pressure level (m)

# Broadcast and mask
mask = z_levels >= ds.zsurf
v_masked = ds.where(mask)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 19
#      15 z_levels = H * np.log(ps / p_pa)
#      16 # height of each pressure level (m)
#      17
#      18 # Broadcast and mask
# ---> 19 mask = z_levels >= ds.zsurf
#      20 v_masked = ds.where(mask)
#
# File ~/opt/anaconda3/envs/llj/lib/python3.12/site-packages/xarray/core/common.py:306, in AttrAccessMixin.__getattr__(self, name)
#     304         with suppress(KeyError):
#     305             return source[name]
# --> 306 raise AttributeError(
#     307     f"{type(self).__name__!r} object has no attribute {name!r}"
#     308 )
#
# AttributeError: 'Dataset' object has no attribute 'zsurf'

# %%
# new masking function

z_surf = ds['height'].isel(pfull=-1).mean(dim='time').compute()

plt.figure(figsize=(12, 4))
z_surf.plot(x='lon', y='lat', cmap='terrain', levels=20)
plt.title('Surface Height Proxy (lowest model level)')
plt.show()

# %%
Rd = 287.05
g0 = 9.80665
T0 = 270.0
H = (Rd * T0) / g0

z_surf = ds['height'].isel(pfull=-1).mean(dim='time').compute()

# Analytic height of each pressure level — 1D (pfull,), fixed, no time dependence
p_pa = ds['pfull'] * 100.0
ps = 1e5
z_hydrostatic = H * np.log(ps / p_pa)  # shape: (pfull,)

# Mask: keep levels where analytic height >= terrain height
# z_hydrostatic is (pfull,), z_surf is (lat, lon) — broadcasts to (pfull, lat, lon)
mask = z_hydrostatic >= z_surf

vcomp_masked = ds['vcomp'].where(mask)

# %%
# start plotting
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

sns.set_style('white')
sns.despine(left=True, right=True, top=True, bottom=True)

cmap = plt.get_cmap("RdBu_r").copy()
cmap.set_bad(color='darkgray')

# %%
plotdata = ds.ps.isel(time=1).sel(lat=-23, method='nearest').sel(lon=slice(270, 330))
plotdata.plot()
plt.title('Surface Pressure (Pa) at Month 0')
plt.show()

# %%
# VComp — Meridional Wind Component
vcomp_months = vcomp_masked.compute()

# Create subplots: 3 rows × 4 columns = 12 months
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(16, 10), sharex=True, sharey=True)

# Flatten axes array for easy iteration
axes = axes.flatten()

# Loop through months 12–23
for i, t in enumerate(range(24, 36)):
    ax = axes[i]
    v = vcomp_months.isel(time=t).sel(lat=-23, method='nearest').sel(lon=slice(270, 330))
    v.plot(ax=ax, x='lon', y='pfull', yincrease=False, add_colorbar=False, vmin=-12, vmax=12, cmap=cmap, add_labels=False)
    
    ax.set_title(f'Month {t}')
    ax.set_ylim(1000, 300)


# Add a shared colorbar
fig.subplots_adjust(right=0.88)
cbar_ax = fig.add_axes([0.9, 0.15, 0.02, 0.7])  # [left, bottom, width, height]
mappable = v.plot(
    x='lon', y='pfull', yincrease=False,
    add_colorbar=True, cbar_ax=cbar_ax,
    vmin=-12, vmax=12, cmap="RdBu_r", add_labels=False
)
mappable.colorbar.set_label("Meridional Wind Component\n[m/s]", fontsize=12)

# Add shared labels
fig.suptitle('Meridional Wind\n Zonal Cross-Section of 23.7 Degrees South', fontsize=16)
fig.text(0.5, 0.04, 'Longitude\n[Degrees East]', ha='center')
fig.text(0.06, 0.5, 'Pressure\n[hPa]', va='center', rotation='vertical')

plt.tight_layout(rect=[0.08, 0.06, 0.88, 1])
plt.savefig('../figures/idealized cross-sections/Meridional-Wind.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 36
#      33 fig.text(0.06, 0.5, 'Pressure\n[hPa]', va='center', rotation='vertical')
#      35 plt.tight_layout(rect=[0.08, 0.06, 0.88, 1])
# ---> 36 plt.savefig('../figures/idealized cross-sections/Meridional-Wind.png')
#      37 plt.show()
#
# File ~/opt/anaconda3/envs/llj/lib/python3.12/site-packages/matplotlib/pyplot.py:1251, in savefig(*args, **kwargs)
#    1248 fig = gcf()
#    1249 # savefig default implementation has no return, so mypy is unhappy
#    1250 # presumably this is here because subclasses can return?
# -> 1251 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1252 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1253 return res
#
# File ~/opt/anaconda3/envs/llj/lib/python3.12/site-packages/matplotlib/figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# -> 3490 self.canvas.print_figure(fname, **kwargs)
#
# File ~/opt/anaconda3/envs/llj/lib/python3.12/site-packages/matplotlib/backend_bases.py:2184, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2180 try:
#    2181     # _get_renderer may change the figure dpi (as vector formats
#    2182     # force the figure dpi to 72), so we need to set it again here.
#    2183     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2184         result = print_method(
#    2185             filename,
#    2186             facecolor=facecolor,
#    2187             edgecolor=edgecolor,
#    2188             orientation=orientation,
#    2189             bbox_inches_restore=_bbox_inches_restore,
#    2190             **kwargs)
#    2191 finally:
#    2192     if bbox_inches and restore_bbox:
#
# File ~/opt/anaconda3/envs/llj/lib/python3.12/site-packages/matplotlib/backend_bases.py:2040, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2036     optional_kws = {  # Passed by print_figure for other renderers.
#    2037         "dpi", "facecolor", "edgecolor", "orientation",
#    2038         "bbox_inches_restore"}
#    2039     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2040     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2041         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2042 else:  # Let third-parties do as they see fit.
#    2043     print_method = meth
#
# File ~/opt/anaconda3/envs/llj/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:481, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     434 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     435     """
#     436     Write the figure to a PNG file.
#     437
#    (...)    479         *metadata*, including the default 'Software' key.
#     480     """
# --> 481     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~/opt/anaconda3/envs/llj/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:430, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     425 """
#     426 Draw the canvas, then save it using `.image.imsave` (to which
#     427 *pil_kwargs* and *metadata* are forwarded).
#     428 """
#     429 FigureCanvasAgg.draw(self)
# --> 430 mpl.image.imsave(
#     431     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     432     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/opt/anaconda3/envs/llj/lib/python3.12/site-packages/matplotlib/image.py:1657, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1655 pil_kwargs.setdefault("format", format)
#    1656 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1657 image.save(fname, **pil_kwargs)
#
# File ~/opt/anaconda3/envs/llj/lib/python3.12/site-packages/PIL/Image.py:2576, in Image.save(self, fp, format, **params)
#    2574         fp = builtins.open(filename, "r+b")
#    2575     else:
# -> 2576         fp = builtins.open(filename, "w+b")
#    2577 else:
#    2578     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../figures/idealized cross-sections/Meridional-Wind.png'

# %%
# Omega — Vertical Velocity
omega_months = ds.omega

# plotting
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(16, 10), sharex=True, sharey=True)

# Flatten axes array for easy iteration
axes = axes.flatten()

# Loop through months 12–23
for i, t in enumerate(range(24, 36)):
    ax = axes[i]
    vor = omega_months.isel(time=t).sel(lat=-23, method='nearest').sel(lon=slice(270, 330))
    vor.plot(ax=ax, x='lon', y='pfull', yincrease=False, add_colorbar=False, vmin=-0.4, vmax=0.4, cmap=cmap, add_labels=False)
    
    ax.set_title(f'Month {t}')
    ax.set_ylim(1000, 300)


# Add a shared colorbar
fig.subplots_adjust(right=0.88)
cbar_ax = fig.add_axes([0.9, 0.15, 0.02, 0.7])  # [left, bottom, width, height]
mappable = vor.plot(
    x='lon', y='pfull', yincrease=False,
    add_colorbar=True, cbar_ax=cbar_ax,
    vmin=-0.4, vmax=0.4, cmap="RdBu_r", add_labels=False
)
mappable.colorbar.set_label("dp/dt Vertical Velocity\n[Pa/sec]", fontsize=12)

# Add shared labels
fig.suptitle('Vertical Velocity\n Zonal Cross-Section of 23.7 Degrees South', fontsize=16)
fig.text(0.5, 0.04, 'Longitude\n[Degrees East]', ha='center')
fig.text(0.06, 0.5, 'Pressure\n[hPa]', va='center', rotation='vertical')

plt.tight_layout(rect=[0.08, 0.06, 0.88, 1])
plt.savefig('../figures/idealized cross-sections/Vertical-Velocity.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 36
#      33 fig.text(0.06, 0.5, 'Pressure\n[hPa]', va='center', rotation='vertical')
#      35 plt.tight_layout(rect=[0.08, 0.06, 0.88, 1])
# ---> 36 plt.savefig('../figures/idealized cross-sections/Vertical-Velocity.png')
#      37 plt.show()
#
# File ~/opt/anaconda3/envs/llj/lib/python3.12/site-packages/matplotlib/pyplot.py:1251, in savefig(*args, **kwargs)
#    1248 fig = gcf()
#    1249 # savefig default implementation has no return, so mypy is unhappy
#    1250 # presumably this is here because subclasses can return?
# -> 1251 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1252 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1253 return res
#
# File ~/opt/anaconda3/envs/llj/lib/python3.12/site-packages/matplotlib/figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# -> 3490 self.canvas.print_figure(fname, **kwargs)
#
# File ~/opt/anaconda3/envs/llj/lib/python3.12/site-packages/matplotlib/backend_bases.py:2184, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2180 try:
#    2181     # _get_renderer may change the figure dpi (as vector formats
#    2182     # force the figure dpi to 72), so we need to set it again here.
#    2183     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2184         result = print_method(
#    2185             filename,
#    2186             facecolor=facecolor,
#    2187             edgecolor=edgecolor,
#    2188             orientation=orientation,
#    2189             bbox_inches_restore=_bbox_inches_restore,
#    2190             **kwargs)
#    2191 finally:
#    2192     if bbox_inches and restore_bbox:
#
# File ~/opt/anaconda3/envs/llj/lib/python3.12/site-packages/matplotlib/backend_bases.py:2040, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2036     optional_kws = {  # Passed by print_figure for other renderers.
#    2037         "dpi", "facecolor", "edgecolor", "orientation",
#    2038         "bbox_inches_restore"}
#    2039     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2040     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2041         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2042 else:  # Let third-parties do as they see fit.
#    2043     print_method = meth
#
# File ~/opt/anaconda3/envs/llj/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:481, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     434 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     435     """
#     436     Write the figure to a PNG file.
#     437
#    (...)    479         *metadata*, including the default 'Software' key.
#     480     """
# --> 481     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~/opt/anaconda3/envs/llj/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:430, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     425 """
#     426 Draw the canvas, then save it using `.image.imsave` (to which
#     427 *pil_kwargs* and *metadata* are forwarded).
#     428 """
#     429 FigureCanvasAgg.draw(self)
# --> 430 mpl.image.imsave(
#     431     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     432     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/opt/anaconda3/envs/llj/lib/python3.12/site-packages/matplotlib/image.py:1657, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1655 pil_kwargs.setdefault("format", format)
#    1656 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1657 image.save(fname, **pil_kwargs)
#
# File ~/opt/anaconda3/envs/llj/lib/python3.12/site-packages/PIL/Image.py:2576, in Image.save(self, fp, format, **params)
#    2574         fp = builtins.open(filename, "r+b")
#    2575     else:
# -> 2576         fp = builtins.open(filename, "w+b")
#    2577 else:
#    2578     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../figures/idealized cross-sections/Vertical-Velocity.png'

# %%
# Vort — Vorticity — Curl of Velocity
vor_months = ds.vor

# plotting
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(16, 10), sharex=True, sharey=True)

# Flatten axes array for easy iteration
axes = axes.flatten()

# Loop through months 12–23
for i, t in enumerate(range(24, 36)):
    ax = axes[i]
    vor = vor_months.isel(time=t).sel(lat=-23, method='nearest').sel(lon=slice(270, 330))
    vor.plot(ax=ax, x='lon', y='pfull', yincrease=False, add_colorbar=False, cmap=cmap, add_labels=False, vmin=-0.00006, vmax=0.00006) 
    
    ax.set_title(f'Month {t}')
    ax.set_ylim(1000, 300)


# Add a shared colorbar
fig.subplots_adjust(right=0.88)
cbar_ax = fig.add_axes([0.9, 0.15, 0.02, 0.7])  # [left, bottom, width, height]
mappable = vor.plot(
    x='lon', y='pfull', yincrease=False,
    add_colorbar=True, cbar_ax=cbar_ax,
    cmap="RdBu_r", add_labels=False,
    vmin=-0.00006, vmax=0.00006
)

mappable.colorbar.set_label("Vorticity\n[sec**-1]", fontsize=12)

# Add shared labels
fig.suptitle('Vorticity\n Zonal Cross-Section of 23.7 Degrees South', fontsize=16)
fig.text(0.5, 0.04, 'Longitude\n[Degrees East]', ha='center')
fig.text(0.06, 0.5, 'Pressure\n[hPa]', va='center', rotation='vertical')

plt.tight_layout(rect=[0.08, 0.06, 0.88, 1])
plt.savefig('../figures/idealized cross-sections/Vorticity.png')
plt.show()

# %%
# calculate Equatorial Kelvin Waves?p
